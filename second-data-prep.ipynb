# %%
import pandas as pd
from datetime import datetime, time

# Load file into dataframe
folder_path = 'c:/Users/aoife/Documents/Project/DataTables/'
save_path = 'C:/Users/aoife/Documents/Project/filtered_data/'

# %% [markdown]
# # Body Mass Index

# %%
# get the average height/body mass for each participant

df_bm = pd.read_csv(folder_path + 'body-mass.csv', usecols=['participantId', 'timestamp', 'value'], parse_dates=['timestamp'])
df_h = pd.read_csv(folder_path + 'height.csv', usecols=['participantId', 'timestamp', 'value'], parse_dates=['timestamp'])

bmi_dfs = [df_bm, df_h]

for df in bmi_dfs:
    if 'value' in df.columns:

        # Convert timestamp to datetime
        df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%dT%H:%M:%SZ')
        # Convert timestamp to date

        # Get the average value for each participant
        df['value'] = df.groupby(['participantId'])['value'].transform('mean')

        # Drop duplicates
        df.drop_duplicates(subset=['participantId'], inplace=True)

        print(df.head())
        print('----------------\n')

# Sort by participantId
df_bm.sort_values(by=['participantId'], inplace=True)
df_h.sort_values(by=['participantId'], inplace=True)

# Rename value columns
df_bm.rename(columns={'value': 'bodyMass_kg'}, inplace=True)
df_h.rename(columns={'value': 'height_m'}, inplace=True)

# Merge on participantId

df_bmi = pd.merge(df_bm, df_h, on='participantId')

df_bmi['startDate'] = df_bmi['timestamp_x'].dt.date

df_bmi['bmi'] = df_bmi['bodyMass_kg'] / (df_bmi['height_m'] ** 2)

# drop unnecessary columns and duplicates
df_bmi.drop(columns=['timestamp_x', 'timestamp_y'], inplace=True)
df_bmi.drop_duplicates(subset=['participantId'], inplace=True)

print(df_bmi.shape)
# Out:
#                           participantId                 timestamp       value
# 0  11b2bf4d-6020-4a86-81bd-237c5616c649 2016-08-24 23:56:14+00:00   97.976000
# 1  9cbbb597-30c0-4f48-aebd-7fe58c627cf6 2016-03-16 02:33:20+00:00   63.503000
# 2  941e9fa4-6ba5-41f5-9bcc-805849d751b8 2017-01-01 14:07:00+00:00   96.666000
# 3  41c683b0-f6c4-4a6a-8dd2-4b9a3dd30a32 2016-03-30 02:24:59+00:00  112.846333
# 4  35fbae45-0f21-45ea-8ed7-8d3361a29b86 2016-07-18 17:45:38+00:00   68.690083
# ----------------
#
#                           participantId                 timestamp   value
# 0  11b2bf4d-6020-4a86-81bd-237c5616c649 2016-08-24 23:56:14+00:00  1.6256
# 1  9cbbb597-30c0-4f48-aebd-7fe58c627cf6 2016-03-16 02:33:20+00:00  1.6510
# 2  941e9fa4-6ba5-41f5-9bcc-805849d751b8 2017-01-01 14:07:00+00:00  1.8288
# 3  1cba6631-3fb8-4c18-904f-ab56fe82833d 2016-03-07 05:54:00+00:00  1.5494
# 4  eb2c4ff0-54e2-4c34-b73d-003e3e0427ad 2016-04-02 07:17:47+00:00  1.7018
# ----------------
#
# (1790, 5)

# %% [markdown]
# # Heart Rate

# %%
import pandas as pd
from datetime import time
import numpy as np

df_hr = pd.read_csv(folder_path + 'heart-rate.csv', usecols=['participantId', 'timestamp', 'startTime', 'endTime', 'value'], parse_dates=['timestamp', 'startTime', 'endTime'])

# Convert startTime and endTime to datetime and get date
df_hr['startTime'] = pd.to_datetime(df_hr['startTime'])
df_hr['endTime'] = pd.to_datetime(df_hr['endTime'])
df_hr['startDate'] = df_hr['startTime'].dt.date

# Remove rows with duplicated participantId, startTime, and endTime
df_hr.drop_duplicates(subset=['participantId', 'startTime', 'endTime'], inplace=True)

# Initialize time of day columns as NaN
df_hr['morning_hr'] = np.nan
df_hr['afternoon_hr'] = np.nan
df_hr['evening_hr'] = np.nan
df_hr['night_hr'] = np.nan

# Define time boundaries
# TODO look into what times are best for these
morning_end = time(12, 0)
afternoon_end = time(18, 0)
evening_end = time(23, 59)
night_end = time(6, 0)

# Classify each heart rate entry into the correct time of day
for index, row in df_hr.iterrows():
    start_time = row['startTime'].time()
    if night_end <= start_time < morning_end:
        df_hr.at[index, 'morning_hr'] = row['value']
    elif morning_end <= start_time < afternoon_end:
        df_hr.at[index, 'afternoon_hr'] = row['value']
    elif afternoon_end <= start_time < evening_end:
        df_hr.at[index, 'evening_hr'] = row['value']
    else:
        df_hr.at[index, 'night_hr'] = row['value']

# Calculate a temporary daily average heart rate excluding NaN values for accurate imputation
df_hr['temp_daily_avg_hr'] = df_hr[['morning_hr', 'afternoon_hr', 'evening_hr', 'night_hr']].mean(axis=1, skipna=True)

# Group by participant and date to compute an accurate daily average for imputation, excluding days with all NaN values
accurate_daily_avg = df_hr.groupby(['participantId', 'startDate'])['temp_daily_avg_hr'].mean().reset_index().rename(columns={'temp_daily_avg_hr': 'accurate_daily_avg_hr'})

# Merge this accurate daily average back into the original dataframe
df_hr = pd.merge(df_hr, accurate_daily_avg, on=['participantId', 'startDate'], how='left')

# Impute missing values in each period with the recalculated accurate daily average
for period in ['morning_hr', 'afternoon_hr', 'evening_hr', 'night_hr']:
    df_hr[period] = df_hr[period].fillna(df_hr['accurate_daily_avg_hr'])

# Calculate mean, max, and min heart rate for each period (includes imputed values)
df_hr_aggregated = df_hr.groupby(['participantId', 'startDate']).agg(
    mean_hr_morning=('morning_hr', 'mean'),
    max_hr_morning=('morning_hr', 'max'),
    min_hr_morning=('morning_hr', 'min'),
    mean_hr_afternoon=('afternoon_hr', 'mean'),
    max_hr_afternoon=('afternoon_hr', 'max'),
    min_hr_afternoon=('afternoon_hr', 'min'),
    mean_hr_evening=('evening_hr', 'mean'),
    max_hr_evening=('evening_hr', 'max'),
    min_hr_evening=('evening_hr', 'min'),
    mean_hr_night=('night_hr', 'mean'),
    max_hr_night=('night_hr', 'max'),
    min_hr_night=('night_hr', 'min')
).reset_index()

# Drop the temporary columns
df_hr_summary = df_hr[['participantId', 'startDate', 'morning_hr', 'afternoon_hr', 'evening_hr', 'night_hr']].drop_duplicates(subset=['participantId', 'startDate'])

# Merge the aggregated values
df_hr_final = pd.merge(df_hr_summary, df_hr_aggregated, on=['participantId', 'startDate'], how='left')

df_hr_final.drop_duplicates(subset=['participantId', 'startDate'], keep='first', inplace=True)

# savr to csv just to check all the entries
df_hr_final.to_csv(save_path + 'heart_rate_summary.csv', index=False)

print(df_hr_final.head())
# Out:
#                           participantId   startDate  morning_hr  afternoon_hr  \
# 0  06bc6ebb-a233-469f-8091-90256f656b1b  2016-03-13    1.173082      1.500000
# 1  2214f4fd-1ae0-4804-8663-b01c5f6d142c  2016-03-02    1.260992      1.333000
# 2  b2571643-4aec-492f-bc7f-6f23c7fe239a  2018-10-03    1.300000      1.263071
# 3  b1406c4e-e6ac-4297-a9e4-335ca5ef04de  2019-01-24    1.203742      1.203742
# 4  b1406c4e-e6ac-4297-a9e4-335ca5ef04de  2019-01-23    1.903400      1.903400
#
#    evening_hr  night_hr  mean_hr_morning  max_hr_morning  min_hr_morning  \
# 0    1.173082  1.173082         1.159673        1.233000        0.867000
# 1    1.260992  1.260992         1.260992        1.260992        1.260992
# 2    1.263071  1.263071         1.285036        1.533000        1.133000
# 3    1.203742  1.333000         1.203742        1.203742        1.203742
# 4    1.917000  1.903400         1.903400        1.903400        1.903400
#
#    mean_hr_afternoon  max_hr_afternoon  min_hr_afternoon  mean_hr_evening  \
# 0           1.185244          2.133000          0.850000         1.174329
# 1           1.261396          1.783000          1.050000         1.260587
# 2           1.241107          1.263071          1.183000         1.263071
# 3           1.203742          1.203742          1.203742         1.193823
# 4           1.903400          1.903400          1.903400         1.903400
#
#    max_hr_evening  min_hr_evening  mean_hr_night  max_hr_night  min_hr_night
# 0        1.617000        1.083000       1.173082      1.173082      1.173082
# 1        1.417000        1.150000       1.260992      1.260992      1.260992
# 2        1.263071        1.263071       1.263071      1.263071      1.263071
# 3        1.203742        1.000000       1.213661      1.400000      0.983000
# 4        1.917000        1.883000       1.903400      1.903400      1.903400

# %% [markdown]
# # Step Count

# %%
import pandas as pd
from datetime import time, datetime
import numpy as np

df_sc = pd.read_csv(folder_path + 'step-count.csv', usecols=['participantId', 'timestamp', 'startTime', 'endTime', 'value'], parse_dates=['timestamp', 'startTime', 'endTime'])

df_sc['startTime'] = pd.to_datetime(df_sc['startTime'], utc=True)
df_sc['endTime'] = pd.to_datetime(df_sc['endTime'], utc=True)
df_sc['startDate'] = df_sc['startTime'].dt.date

df_sc['duration'] = (df_sc['endTime'] - df_sc['startTime']).dt.total_seconds()


# Calculate total steps per day for each participant
df_sc['totalSteps'] = df_sc.groupby(['participantId', 'startDate'])['value'].transform('sum')

# Calculate the total duration per day for each participant
df_sc['stepsTotalDuration'] = df_sc.groupby(['participantId', 'startDate'])['duration'].transform('sum')
df_sc['steps_per_hour'] = df_sc['totalSteps'] / (df_sc['stepsTotalDuration'] / (60*60))

# Time boundaries
morning_end = time(12, 0)
afternoon_end = time(18, 0)
evening_end = time(23, 59)
night_end = time(6, 0)

# Initialize step counts for different times of day as NaN
df_sc['morningSteps'] = np.nan
df_sc['afternoonSteps'] = np.nan
df_sc['eveningSteps'] = np.nan
df_sc['nightSteps'] = np.nan

# Classify steps into different times of the day
for index, row in df_sc.iterrows():
    start_time = row['startTime'].time()
    if night_end < start_time <= morning_end:
        df_sc.at[index, 'morningSteps'] = row['value']
    elif morning_end < start_time <= afternoon_end:
        df_sc.at[index, 'afternoonSteps'] = row['value']
    elif afternoon_end < start_time <= evening_end:
        df_sc.at[index, 'eveningSteps'] = row['value']
    else:
        df_sc.at[index, 'nightSteps'] = row['value']

# aggregate steps into totals for each time
df_summary = df_sc.groupby(['participantId', 'startDate']).agg(
    morningStepsTotal=('morningSteps', 'sum'),
    afternoonStepsTotal=('afternoonSteps', 'sum'),
    eveningStepsTotal=('eveningSteps', 'sum'),
    nightStepsTotal=('nightSteps', 'sum'),
    totalSteps=('totalSteps', 'first'), 
    stepsTotalDuration=('stepsTotalDuration', 'first')
).reset_index()

# drop unnecessary columns
df_sc.drop(columns=['morningSteps', 'afternoonSteps', 'eveningSteps', 'nightSteps', 'duration', 'value', 'startTime', 'endTime', 'totalSteps', 'stepsTotalDuration'], inplace=True)
# merge back together
df_sc = pd.merge(df_sc, df_summary, on=['participantId', 'startDate'], how='left')

# Drop duplicates
df_sc.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)

df_sc.to_csv(save_path + 'step_count_summary.csv', index=False)

print(df_sc.head())
# Out:
#                             participantId                 timestamp  \
# 0    1f649060-680a-4c80-a551-be38ce46cb94 2016-05-14 03:04:03+00:00
# 21   1f649060-680a-4c80-a551-be38ce46cb94 2016-05-14 03:04:03+00:00
# 91   1f649060-680a-4c80-a551-be38ce46cb94 2016-05-14 03:04:03+00:00
# 116  1f649060-680a-4c80-a551-be38ce46cb94 2016-05-14 03:04:07+00:00
# 127  1f649060-680a-4c80-a551-be38ce46cb94 2016-05-14 03:04:07+00:00
#
#       startDate  steps_per_hour  morningStepsTotal  afternoonStepsTotal  \
# 0    2016-03-22     3296.571899                0.0               4422.0
# 21   2016-03-23     3838.334779                0.0               8885.0
# 91   2016-03-24     4264.419532               20.0               7859.0
# 116  2016-03-29     3292.721759              118.0               8130.0
# 127  2016-03-30     3490.214189                0.0               6803.0
#
#      eveningStepsTotal  nightStepsTotal  totalSteps  stepsTotalDuration
# 0               5529.0             66.0       10017             10939.0
# 21              5568.0            299.0       14752             13836.0
# 91              5569.0           2296.0       15744             13291.0
# 116             5256.0            973.0       14477             15828.0
# 127             4224.0           1149.0       12176             12559.0

# %% [markdown]
# # Distance Walking/Running

# %%
import pandas as pd
from datetime import time
import numpy as np

df_dwr = pd.read_csv(folder_path + 'distance-walking-running.csv', usecols=['participantId', 'timestamp', 'startTime', 'endTime', 'value'], parse_dates=['timestamp', 'startTime', 'endTime'])

df_dwr['startTime'] = pd.to_datetime(df_dwr['startTime'], utc=True)
df_dwr['endTime'] = pd.to_datetime(df_dwr['endTime'], utc=True)
df_dwr['startDate'] = df_dwr['startTime'].dt.date

# Calculate total distance and duration
df_dwr['totalDistance'] = df_dwr.groupby(['participantId', 'startDate'])['value'].transform('sum')
df_dwr['duration'] = (df_dwr['endTime'] - df_dwr['startTime']).dt.total_seconds()
df_dwr['dwrTotalDuration'] = df_dwr.groupby(['participantId', 'startDate'])['duration'].transform('sum')
df_dwr['dist_per_hour'] = df_dwr['totalDistance'] / (df_dwr['dwrTotalDuration'] / (60*60))

# Initialize distances for different times
df_dwr['morningDist'] = np.nan
df_dwr['afternoonDist'] = np.nan
df_dwr['eveningDist'] = np.nan
df_dwr['nightDist'] = np.nan

# Define time boundaries
morning_end = time(12, 0)
afternoon_end = time(18, 0)
evening_end = time(23, 59)
night_end = time(6, 0)

# Classify distances into times of day
for index, row in df_dwr.iterrows():
    start_time = row['startTime'].time()
    if night_end < start_time <= morning_end:
        df_dwr.at[index, 'morningDist'] = row['value']
    elif morning_end < start_time <= afternoon_end:
        df_dwr.at[index, 'afternoonDist'] = row['value']
    elif afternoon_end < start_time <= evening_end:
        df_dwr.at[index, 'eveningDist'] = row['value']
    else:
        df_dwr.at[index, 'nightDist'] = row['value']

# Aggregate daily distances
df_summary = df_dwr.groupby(['participantId', 'startDate']).agg(
    morningDistance=('morningDist', 'sum'),
    afternoonDistance=('afternoonDist', 'sum'),
    eveningDistance=('eveningDist', 'sum'),
    nightDistance=('nightDist', 'sum')
).reset_index()

# Merge summary back into df_dwr
df_dwr = pd.merge(df_dwr.drop(columns=['morningDist', 'afternoonDist', 'eveningDist', 'nightDist']), df_summary, on=['participantId', 'startDate'], how='left')

# Drop duplicates
df_dwr.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)

print(df_dwr.shape)

df_dwr.to_csv(save_path + 'distance_walk_run_summary.csv', index=False)
# Out:
# (11507, 14)

# %% [markdown]
# # AM check-in

# %%
'''
df_amch = pd.read_csv(folder_path + 'am-checkin.csv', usecols=['participantId', 'timestamp', 'AMCH1', 'AMCH2', 'AMCH2A','AMCH3','AMCH3A','AMCH4','AMCH5'], parse_dates=['timestamp'])

# fill NaN values of AMCH2A and AMCH3A with 0
df_amch['AMCH2A'] = df_amch['AMCH2A'].fillna(0)
df_amch['AMCH3A'] = df_amch['AMCH3A'].fillna(0)

df_amch['timestamp'] = pd.to_datetime(df_amch['timestamp'], utc=True)

df_amch['startDate'] = df_amch['timestamp'].dt.date

df_amch.drop(columns=['timestamp'], inplace=True)

# drop amch1, amch4
df_amch.drop(columns=['AMCH1', 'AMCH4'], inplace=True)

# for amch2, change true to 1 and false to 0
df_amch['AMCH2'] = df_amch['AMCH2'].map({True: 1, False: 0})

# drop any row with NaN values
df_amch = df_amch.dropna()

print(df_amch.shape)
'''
# Out:
# "\ndf_amch = pd.read_csv(folder_path + 'am-checkin.csv', usecols=['participantId', 'timestamp', 'AMCH1', 'AMCH2', 'AMCH2A','AMCH3','AMCH3A','AMCH4','AMCH5'], parse_dates=['timestamp'])\n\n# fill NaN values of AMCH2A and AMCH3A with 0\ndf_amch['AMCH2A'] = df_amch['AMCH2A'].fillna(0)\ndf_amch['AMCH3A'] = df_amch['AMCH3A'].fillna(0)\n\ndf_amch['timestamp'] = pd.to_datetime(df_amch['timestamp'], utc=True)\n\ndf_amch['startDate'] = df_amch['timestamp'].dt.date\n\ndf_amch.drop(columns=['timestamp'], inplace=True)\n\n# drop amch1, amch4\ndf_amch.drop(columns=['AMCH1', 'AMCH4'], inplace=True)\n\n# for amch2, change true to 1 and false to 0\ndf_amch['AMCH2'] = df_amch['AMCH2'].map({True: 1, False: 0})\n\n# drop any row with NaN values\ndf_amch = df_amch.dropna()\n\nprint(df_amch.shape)\n"

# %% [markdown]
# # PM check-in

# %%
'''
df_pmch = pd.read_csv(folder_path + 'pm-checkin.csv', usecols=['participantId', 'timestamp', 'alcohol', 'caffeine', 'NapCount','PMCH1','PMCH2A','PMCH3'], parse_dates=['timestamp'])

df_pmch['timestamp'] = pd.to_datetime(df_pmch['timestamp'], utc=True)

df_pmch['startDate'] = df_pmch['timestamp'].dt.date

df_pmch['PMCH2A'] = df_pmch['PMCH2A'].fillna(0)
df_pmch['NapCount'] = df_pmch['NapCount'].fillna(0)
df_pmch['alcohol'] = df_pmch['alcohol'].fillna(0)
df_pmch['caffeine'] = df_pmch['caffeine'].fillna(0)

df_pmch['medication'] = 0

def check_medication(value):
    return '100' in str(value).split(',')

df_pmch['medication'] = df_pmch.apply(lambda row: '1' if check_medication(row['PMCH3']) else row['medication'], axis=1)

df_pmch.drop(columns=['timestamp'], inplace=True)
df_pmch.drop(columns=['PMCH3'], inplace=True)
df_pmch = df_pmch.dropna()

print(df_pmch.shape)

'''
# Out:
# "\ndf_pmch = pd.read_csv(folder_path + 'pm-checkin.csv', usecols=['participantId', 'timestamp', 'alcohol', 'caffeine', 'NapCount','PMCH1','PMCH2A','PMCH3'], parse_dates=['timestamp'])\n\ndf_pmch['timestamp'] = pd.to_datetime(df_pmch['timestamp'], utc=True)\n\ndf_pmch['startDate'] = df_pmch['timestamp'].dt.date\n\ndf_pmch['PMCH2A'] = df_pmch['PMCH2A'].fillna(0)\ndf_pmch['NapCount'] = df_pmch['NapCount'].fillna(0)\ndf_pmch['alcohol'] = df_pmch['alcohol'].fillna(0)\ndf_pmch['caffeine'] = df_pmch['caffeine'].fillna(0)\n\ndf_pmch['medication'] = 0\n\ndef check_medication(value):\n    return '100' in str(value).split(',')\n\ndf_pmch['medication'] = df_pmch.apply(lambda row: '1' if check_medication(row['PMCH3']) else row['medication'], axis=1)\n\ndf_pmch.drop(columns=['timestamp'], inplace=True)\ndf_pmch.drop(columns=['PMCH3'], inplace=True)\ndf_pmch = df_pmch.dropna()\n\nprint(df_pmch.shape)\n\n"

# %% [markdown]
# # Sleep Quality

# %%
df_sq = pd.read_csv(folder_path + 'sleep-quality-checker.csv', usecols=['participantId', 'timestamp', 'value'], parse_dates=['timestamp'])

df_sq['timestamp'] = pd.to_datetime(df_sq['timestamp'], utc=True)

df_sq['startDate'] = df_sq['timestamp'].dt.date

# drop duplicates
df_sq.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)

# drop unnecessary columns
df_sq.drop(columns=['timestamp'], inplace=True)

df_sq.rename(columns={'value': 'ssq_score'}, inplace=True)

print(df_sq.head())
print(df_sq.shape)
# Out:
#                           participantId  ssq_score   startDate
# 0  b4ebf7dd-4e30-4f7b-8ee8-5493a19c8c9f          4  2016-09-27
# 1  c3993552-69cb-45e4-b18a-5e6eecefb825          4  2016-03-07
# 2  78f60bd3-34f3-489e-a352-f9df564641c3          4  2016-03-05
# 3  9da1a89a-2145-4cca-b356-7b58aa7be8b0          4  2016-09-27
# 4  4aad9dbe-dd9e-4832-a198-3bd563457124          4  2016-03-03
# (39123, 3)

# %% [markdown]
# # Survey Responses

# %%
'''import pandas as pd

# Read in data from surveys
# For each unique participnat in subset_dfs, check if they have answered both surveys. If so, copy the values to each row for that participant
# Note see above code

folder_path = 'c:/Users/aoife/Documents/Project/DataTables/'


df_about_me = pd.read_csv(folder_path + 'about-me.csv', usecols=['participantId', 'timestamp', 'alcohol', 'basic_expenses', 'caffeine', 'daily_activities', 'daily_activities', 'daily_smoking', 'education', 'flexible_work_hours', 'gender', 'good_life', 'hispanic', 'income', 'marital', 'race', 'smoking_status', 'menopause', 'recent_births', 'current_pregnant', 'work_schedule'], parse_dates=['timestamp'])

df_sleep_habits = pd.read_csv(folder_path + 'sleep-habits.csv', usecols=['participantId', 'timestamp', 'alarm_dependency', 'driving_sleepy', 'falling_asleep', 'morning_person', 'nap_duration', 'sleep_lost', 'sleep_needed', 'sleep_partner', 'sleep_time_workday', 'sleep_time_weekend', 'wake_up_choices', 'wake_ups', 'weekly_naps', 'what_wakes_you'], parse_dates=['timestamp'])

'''
# Out:
# "import pandas as pd\n\n# Read in data from surveys\n# For each unique participnat in subset_dfs, check if they have answered both surveys. If so, copy the values to each row for that participant\n# Note see above code\n\nfolder_path = 'c:/Users/aoife/Documents/Project/DataTables/'\n\n\ndf_about_me = pd.read_csv(folder_path + 'about-me.csv', usecols=['participantId', 'timestamp', 'alcohol', 'basic_expenses', 'caffeine', 'daily_activities', 'daily_activities', 'daily_smoking', 'education', 'flexible_work_hours', 'gender', 'good_life', 'hispanic', 'income', 'marital', 'race', 'smoking_status', 'menopause', 'recent_births', 'current_pregnant', 'work_schedule'], parse_dates=['timestamp'])\n\ndf_sleep_habits = pd.read_csv(folder_path + 'sleep-habits.csv', usecols=['participantId', 'timestamp', 'alarm_dependency', 'driving_sleepy', 'falling_asleep', 'morning_person', 'nap_duration', 'sleep_lost', 'sleep_needed', 'sleep_partner', 'sleep_time_workday', 'sleep_time_weekend', 'wake_up_choices', 'wake_ups', 'weekly_naps', 'what_wakes_you'], parse_dates=['timestamp'])\n\n"

# %%
'''# rename the alcolhol column in about_me and sleep_assessment to be more detailed

df_about_me.rename(columns={'alcohol': 'alcohol_consumption'}, inplace=True)

# Convert timestamp to datetime
df_about_me['timestamp'] = pd.to_datetime(df_about_me['timestamp'], utc=True)
df_sleep_habits['timestamp'] = pd.to_datetime(df_sleep_habits['timestamp'], utc=True)

# Change the timestamp to only contain the date
df_about_me['date'] = df_about_me['timestamp'].dt.date
df_sleep_habits['date'] = df_sleep_habits['timestamp'].dt.date
'''
# Out:
# "# rename the alcolhol column in about_me and sleep_assessment to be more detailed\n\ndf_about_me.rename(columns={'alcohol': 'alcohol_consumption'}, inplace=True)\n\n# Convert timestamp to datetime\ndf_about_me['timestamp'] = pd.to_datetime(df_about_me['timestamp'], utc=True)\ndf_sleep_habits['timestamp'] = pd.to_datetime(df_sleep_habits['timestamp'], utc=True)\n\n# Change the timestamp to only contain the date\ndf_about_me['date'] = df_about_me['timestamp'].dt.date\ndf_sleep_habits['date'] = df_sleep_habits['timestamp'].dt.date\n"

# %%
'''# Merge survey dfs

surveys_list = [df_about_me, df_sleep_habits]

# Merge the DataFrames
df_surveys = pd.merge(surveys_list[0], surveys_list[1], on=['participantId', 'date'], how='outer', suffixes=('', '_y'))
#df_surveys = pd.merge(df_surveys, surveys_list[2], on=['participantId', 'date'], how='outer', suffixes=('', '_y'))
'''
# Out:
# "# Merge survey dfs\n\nsurveys_list = [df_about_me, df_sleep_habits]\n\n# Merge the DataFrames\ndf_surveys = pd.merge(surveys_list[0], surveys_list[1], on=['participantId', 'date'], how='outer', suffixes=('', '_y'))\n#df_surveys = pd.merge(df_surveys, surveys_list[2], on=['participantId', 'date'], how='outer', suffixes=('', '_y'))\n"

# %%
'''# Remove duplicates
df_surveys.drop_duplicates(subset=['participantId'], inplace=True)

# For the 'menopause' column, replace NaN with 3
df_surveys['menopause'] = df_surveys['menopause'].fillna(3)

# For the recent_births column, replace NaN with 4
df_surveys['recent_births'] = df_surveys['recent_births'].fillna(4)

# Replace current_pregnant NaN with 0
df_surveys['current_pregnant'] = df_surveys['current_pregnant'].fillna(0)

# replace driving_sleepy NaN with 6
df_surveys['driving_sleepy'] = df_surveys['driving_sleepy'].fillna(6)

# replace falling_asleep NaN with 0
df_surveys['falling_asleep'] = df_surveys['falling_asleep'].fillna(0)

# replace morning_person NaN with 3
df_surveys['morning_person'] = df_surveys['morning_person'].fillna(3)

# replace nap_duration NaN with 6
df_surveys['nap_duration'] = df_surveys['nap_duration'].fillna(6)

# replace sleep_lost NaN with 0
df_surveys['sleep_lost'] = df_surveys['sleep_lost'].fillna(0)

# replace what_wakes_you NaN with 13
df_surveys['what_wakes_you'] = df_surveys['what_wakes_you'].fillna(13)

# Remove unnecessary columns

df_surveys.drop(columns=['timestamp', 'date', 'timestamp_y'], inplace=True)'''
# Out:
# "# Remove duplicates\ndf_surveys.drop_duplicates(subset=['participantId'], inplace=True)\n\n# For the 'menopause' column, replace NaN with 3\ndf_surveys['menopause'] = df_surveys['menopause'].fillna(3)\n\n# For the recent_births column, replace NaN with 4\ndf_surveys['recent_births'] = df_surveys['recent_births'].fillna(4)\n\n# Replace current_pregnant NaN with 0\ndf_surveys['current_pregnant'] = df_surveys['current_pregnant'].fillna(0)\n\n# replace driving_sleepy NaN with 6\ndf_surveys['driving_sleepy'] = df_surveys['driving_sleepy'].fillna(6)\n\n# replace falling_asleep NaN with 0\ndf_surveys['falling_asleep'] = df_surveys['falling_asleep'].fillna(0)\n\n# replace morning_person NaN with 3\ndf_surveys['morning_person'] = df_surveys['morning_person'].fillna(3)\n\n# replace nap_duration NaN with 6\ndf_surveys['nap_duration'] = df_surveys['nap_duration'].fillna(6)\n\n# replace sleep_lost NaN with 0\ndf_surveys['sleep_lost'] = df_surveys['sleep_lost'].fillna(0)\n\n# replace what_wakes_you NaN with 13\ndf_surveys['what_wakes_you'] = df_surveys['what_wakes_you'].fillna(13)\n\n# Remove unnecessary columns\n\ndf_surveys.drop(columns=['timestamp', 'date', 'timestamp_y'], inplace=True)"

# %%
'''def join_multiple_race(row):
    if ',' in str(row):
        return 6
    return row

df_surveys['hispanic'] = df_surveys['hispanic'].apply(join_multiple_race)
df_surveys['race'] = df_surveys['race'].apply(join_multiple_race)

def join_multiple_sleep_partner(row):
    if ',' in str(row):
        return 6
    return row

df_surveys['sleep_partner'] = df_surveys['sleep_partner'].apply(join_multiple_sleep_partner)

# create new columns for wakeup reasons

df_surveys['noise_light'] = 0
df_surveys['stress_thinking'] = 0
df_surveys['other_person'] = 0
df_surveys['pain_discomfort'] = 0
df_surveys['nightmares'] = 0
df_surveys['bathroom_urges'] = 0
df_surveys['other_reasons'] = 0

def check_wakeup_reason(row, number):
    if number == 1:
        df_surveys.loc[row.name, 'noise_light'] = 1
    elif number == 2:
        df_surveys.loc[row.name, 'stress_thinking'] = 1
    elif number == 3:
        df_surveys.loc[row.name, 'other_person'] = 1
    elif number == 4:
        df_surveys.loc[row.name, 'pain_discomfort'] = 1
    elif number == 5:
        df_surveys.loc[row.name, 'nightmares'] = 1
    elif number == 6:
        df_surveys.loc[row.name, 'bathroom_urges'] = 1
    else:
        df_surveys.loc[row.name, 'other_reasons'] = 1


for i, row in df_surveys.iterrows():
    if ',' in str(row['what_wakes_you']):
        nums = map(int, row['what_wakes_you'].split(','))
        for number in nums:
            check_wakeup_reason(row, number)
    else:
        check_wakeup_reason(row, int(row['what_wakes_you']))

# Remove what_wakes_you
df_surveys.drop(columns=['what_wakes_you'], inplace=True)

print(df_surveys.head())'''
# Out:
# "def join_multiple_race(row):\n    if ',' in str(row):\n        return 6\n    return row\n\ndf_surveys['hispanic'] = df_surveys['hispanic'].apply(join_multiple_race)\ndf_surveys['race'] = df_surveys['race'].apply(join_multiple_race)\n\ndef join_multiple_sleep_partner(row):\n    if ',' in str(row):\n        return 6\n    return row\n\ndf_surveys['sleep_partner'] = df_surveys['sleep_partner'].apply(join_multiple_sleep_partner)\n\n# create new columns for wakeup reasons\n\ndf_surveys['noise_light'] = 0\ndf_surveys['stress_thinking'] = 0\ndf_surveys['other_person'] = 0\ndf_surveys['pain_discomfort'] = 0\ndf_surveys['nightmares'] = 0\ndf_surveys['bathroom_urges'] = 0\ndf_surveys['other_reasons'] = 0\n\ndef check_wakeup_reason(row, number):\n    if number == 1:\n        df_surveys.loc[row.name, 'noise_light'] = 1\n    elif number == 2:\n        df_surveys.loc[row.name, 'stress_thinking'] = 1\n    elif number == 3:\n        df_surveys.loc[row.name, 'other_person'] = 1\n    elif number == 4:\n        df_surveys.loc[row.name, 'pain_discomfort'] = 1\n    elif number == 5:\n        df_surveys.loc[row.name, 'nightmares'] = 1\n    elif number == 6:\n        df_surveys.loc[row.name, 'bathroom_urges'] = 1\n    else:\n        df_surveys.loc[row.name, 'other_reasons'] = 1\n\n\nfor i, row in df_surveys.iterrows():\n    if ',' in str(row['what_wakes_you']):\n        nums = map(int, row['what_wakes_you'].split(','))\n        for number in nums:\n            check_wakeup_reason(row, number)\n    else:\n        check_wakeup_reason(row, int(row['what_wakes_you']))\n\n# Remove what_wakes_you\ndf_surveys.drop(columns=['what_wakes_you'], inplace=True)\n\nprint(df_surveys.head())"

# %% [markdown]
# # Pulling Everything Together
#
# 1. Add each dataframe to a list
# 2. Gather a list of unique participants
# 3. Choose a number of unique participants, and merge their data across each dataframe
# 4. Continue for all participants
# 5. Remove NaN values
# 6. Concatenate each new dataframe

# %%
# merge function

def merge_dfs(dfs_list, participants):
    merged_df = None
    for df in dfs_list:
        # Filter dataframe for participants we currently work with
        curr_df = df[df['participantId'].isin(participants)]
        if merged_df is None:
            merged_df = curr_df
        else:
            merged_df = pd.merge(merged_df, curr_df, on=['participantId', 'startDate'], how='outer', suffixes=('', '_y'))
    return merged_df

# %%
def get_separate_tables(num_participants):
    
    # Create a list of DataFrames
    dfs_list = [df_bmi, df_hr_final, df_sc, df_dwr, df_sq]	


    # Create a list of all participants
    participants = set(dfs_list[0]['participantId'].unique())

    # Sort the list of participants alphabetically
    participants = sorted(list(participants))
    
    # print length of participants
    print(len(participants))

    result_dfs = []

    while participants:
        # Get the next group of participants
        next_group = participants[:num_participants]

        # Merge the DataFrames for the next group of participants
        merge_df = merge_dfs(dfs_list, next_group)

        print(merge_df.head())

        # Add the merged DataFrame to the list of results
        result_dfs.append(merge_df)

        # Remove the participants that were just used
        participants = participants[num_participants:]

    return result_dfs

# %%
# Call get_separate_tables() and check the resulting dfs

subset_dfs = get_separate_tables(20)

# print the shape of each DataFrame
for i, df in enumerate(subset_dfs):
    print(f"DataFrame {i}: {df.shape}")
# Out:
# 1790
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  00a55fb5-da33-4e2e-ae61-28f589fcc174       51.256    1.5748  2016-05-12
# 1  00d6d2ee-ccea-45c7-9772-b19fd9bef2bf       74.389    1.9050  2018-04-20
# 2  00fd4039-9b5e-4bbb-8295-4983a3f58371       59.874    1.6510  2018-08-15
# 3  0113e483-0fc8-4892-a4fc-0b2f3820dde3       68.039    1.7018  2019-03-06
# 4  013d82d7-b3cc-4007-b00c-4d1d75bab9dd       76.204    1.6002  2018-02-21
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  20.667783    1.400000      1.438426    1.438426  1.438426         1.438137
# 1  20.498343         NaN           NaN         NaN       NaN              NaN
# 2  21.965653    1.290195      1.290195    1.290195  1.383000         1.266626
# 3  23.493130    1.292230      1.000000    1.292230  1.292230         1.292230
# 4  29.759747         NaN           NaN         NaN       NaN              NaN
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...   17.730       3970.370      15.0            8567.0    1668.417416
# 1  ...      NaN            NaN       NaN               NaN            NaN
# 2  ...   21.890         46.270      61.0            1441.0     115.594726
# 3  ...  199.902       5085.913     597.0            7537.0    2429.253921
# 4  ...   11.100         30.590     380.0            1320.0      83.427273
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0          1123.06           2456.180          391.130          0.000
# 1              NaN                NaN              NaN            NaN
# 2             0.00              0.000            0.000         46.270
# 3             0.00           3055.634         1996.413         33.866
# 4             0.00              0.000            0.000         30.590
#
#    ssq_score
# 0        3.0
# 1        NaN
# 2        4.0
# 3        NaN
# 4        3.0
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  041d9018-9fcb-4cdc-9539-9021602ba36c       83.915    1.7780  2016-03-03
# 1  048ba877-5df6-47c4-b485-d3538db9e9b4       81.647    1.7780  2017-11-17
# 2  04908caf-14d4-4f88-8500-5cef40305718       73.482    1.5494  2017-11-04
# 3  04ce20b9-62c3-4082-a281-7ee53dea2897      112.370    1.8288  2016-03-10
# 4  053aa72a-bb4f-4d02-aa73-23404068ef15       85.275    1.7272  2018-02-03
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  26.544594    2.107395      2.107395    2.107395     1.117         2.099205
# 1  25.827164    1.100659      1.100659    1.100659     1.117         1.094458
# 2  30.609333    1.368625      1.368625    1.368625     1.500         1.368625
# 3  33.598350         NaN           NaN         NaN       NaN              NaN
# 4  28.584886         NaN           NaN         NaN       NaN              NaN
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...   45.993       5479.177      62.0            4668.0    4225.586375
# 1  ...   14.400        436.666     365.0            4944.0     317.960680
# 2  ...   80.020         94.330     599.0             691.0     491.444284
# 3  ...    7.258          7.258      19.0              19.0    1375.200000
# 4  ...  131.706        259.690     599.0            2006.0     466.043868
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0          506.009           4396.963              0.0        576.205
# 1          212.107            224.559              0.0          0.000
# 2            0.000              0.000              0.0         94.330
# 3            0.000              0.000              0.0          7.258
# 4            0.000              0.000              0.0        259.690
#
#    ssq_score
# 0        5.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  0814d5bc-d446-45e7-b032-2822b53e4666      81.6470    1.7272  2016-03-03
# 1  081c375d-bae6-42e1-a9bb-3aeb095ba7db      61.2350    1.7526  2016-03-02
# 2  0840ff56-2fa8-4902-ac3b-285a695bc6f3     124.7755    1.9050  2016-09-19
# 3  0851e6c9-8b75-4ef8-8c0c-342fc6f62838     132.9030    1.8542  2016-03-02
# 4  085547e6-7649-4378-93cc-1151c7ce21ca      76.8590    1.7526  2016-03-28
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  27.368751         NaN           NaN         NaN       NaN              NaN
# 1  19.935820    1.150000      1.433406    1.433406  1.433406         1.425104
# 2  34.382651    1.517000      1.396406    1.396406  1.396406         1.462503
# 3  38.656420    1.467000      1.335104    1.335104  1.335104         1.321498
# 4  25.022409    1.387482      1.200000    1.387482  1.387482         1.387482
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...      NaN            NaN       NaN               NaN            NaN
# 1  ...   19.292      22766.896      59.0           23567.0    3477.779336
# 2  ...   21.010       9511.228     468.0           31177.0    1098.258999
# 3  ...  124.169      13602.057     352.0           26978.0    1815.086559
# 4  ...   57.420       6845.260     230.0           12579.0    1959.053661
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              NaN                NaN              NaN            NaN
# 1          142.572          10573.050        12051.274            0.0
# 2         5979.118           2478.050         1054.060            0.0
# 3          908.464          10906.373         1787.220            0.0
# 4            0.000           6189.950          655.310            0.0
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  09d665e2-4aac-46b2-b1be-1219e798969f   100.698000    1.8542  2018-11-11
# 1  09f92ffe-d84a-410f-ad3c-2a58792f570f    99.790000    1.9050  2017-03-25
# 2  0a57fb56-f752-4030-aee7-566ed167db1a    76.657000    1.7780  2016-03-04
# 3  0ab3eab3-24d1-40dd-9775-c52b5f0012de    72.574667    1.6256  2016-03-30
# 4  0ad49adb-241f-421e-a11f-676f4736d649    74.389000    1.7272  2019-02-18
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  29.289212         NaN           NaN         NaN       NaN              NaN
# 1  27.497744    1.565890      1.565890    1.565890     1.450         1.537185
# 2  24.248691    1.266674      1.266674    1.266674     1.467         1.263197
# 3  27.463613    1.408333      1.408333    1.408333     1.300         1.408333
# 4  24.935809         NaN           NaN         NaN       NaN              NaN
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  25.840        100.670     601.0             995.0     364.233166
# 1  ...  12.780       4503.700     585.0           34053.0     476.120166
# 2  ...     NaN            NaN       NaN               NaN            NaN
# 3  ...     NaN            NaN       NaN               NaN            NaN
# 4  ...  19.935        347.562      59.0            1287.0     972.201399
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0             0.00               0.00              0.0        100.670
# 1          3889.68             417.67              0.0        196.350
# 2              NaN                NaN              NaN            NaN
# 3              NaN                NaN              NaN            NaN
# 4             0.00               0.00              0.0        347.562
#
#    ssq_score
# 0        3.0
# 1        NaN
# 2        NaN
# 3        4.0
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  0cdbd2d6-e86b-425e-a566-e2b79a614126       66.678    1.7526  2018-09-17
# 1  0cf02656-84c7-4d0a-9413-9134dcfd5404       91.626    1.6002  2019-04-05
# 2  0d277cbd-b826-4229-b268-056e10c19070       93.440    1.7780  2016-03-02
# 3  0d649960-635d-469e-86ac-fd00858ec24d      127.006    1.8542  2016-04-02
# 4  0d7bb073-6aa2-4701-9d5b-dc6762caf1d6       78.471    1.7526  2018-12-21
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  21.707857    1.021227      1.021227    1.021227  1.300000         1.008942
# 1  35.782460         NaN           NaN         NaN       NaN              NaN
# 2  29.557610    1.654053      1.654053    1.700000  1.654053         1.566148
# 3  36.941207    1.297386      1.250000    1.297386  1.297386         1.297386
# 4  25.547216         NaN           NaN         NaN       NaN              NaN
#
#    ...  value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...    NaN            NaN       NaN               NaN            NaN
# 1  ...   6.34         75.420     551.0            1160.0     234.062069
# 2  ...   2.28       7551.671     360.0           15014.0    1810.711043
# 3  ...  59.98       9708.510      62.0           26931.0    1297.784561
# 4  ...   0.92         13.120       2.0              17.0    2778.352941
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              NaN                NaN              NaN            NaN
# 1             9.62             11.040            54.76           0.00
# 2            26.41           3363.721          4154.18           7.36
# 3             0.00           5216.520          4491.99           0.00
# 4             0.00              0.000             0.00          13.12
#
#    ssq_score
# 0        NaN
# 1        3.0
# 2        NaN
# 3        NaN
# 4        1.0
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  0f9e209f-8ce4-43af-90d1-0faef98526d9       72.575    1.7018  2016-03-22
# 1  0fd7be8c-53c5-4918-a3ce-6ee611f0ef4d       58.967    1.6002  2017-06-28
# 2  0fe6e0fd-d160-4455-b2e1-bd50cd45b90d       88.451    1.7780  2016-03-21
# 3  10331cb1-22f9-40dd-a948-4b51b2e8ecf3      102.965    1.7018  2018-01-14
# 4  1042adac-74a1-4e00-a2a4-eb55a06dd15e       95.708    1.6256  2016-05-09
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  25.059362    1.216667      1.216667    1.216667  1.267000         1.216667
# 1  23.028227    1.419108      1.419108    1.419108  1.617000         1.391390
# 2  27.979454    1.150000      1.306815    1.306815  1.306815         1.303829
# 3  35.552700    1.520711      1.520711    1.667000  1.520711         1.496449
# 4  36.217699         NaN           NaN         NaN       NaN              NaN
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  107.273        550.569     254.0            1197.0    1655.846617
# 1  ...      NaN            NaN       NaN               NaN            NaN
# 2  ...  106.768      20997.887      60.0           38555.0    1960.637873
# 3  ...   22.410        354.540     227.0            4637.0     275.252103
# 4  ...    3.960        203.370       3.0             339.0    2159.681416
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0            0.000               0.00            0.000        550.569
# 1              NaN                NaN              NaN            NaN
# 2         2731.016            9785.99         8380.435        100.446
# 3          127.774               0.00          215.726         11.040
# 4            0.000               0.00            0.000        203.370
#
#    ssq_score
# 0        NaN
# 1        3.0
# 2        3.0
# 3        NaN
# 4        3.0
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  1256338b-7a4a-44a6-836d-b21f6dc66ed7       98.430    1.6256  2018-02-08
# 1  1261d637-ebba-4989-b53e-3d97475fe2d2       69.400    1.6764  2017-11-18
# 2  1269d5da-7f98-4433-8cd2-60bb3a027eef       68.946    1.6256  2016-06-11
# 3  12c31dcc-7fd9-4a20-8285-d1d30d6102e4       70.760    1.7018  2016-03-02
# 4  12d01c4f-2ea5-48fe-9140-ee7e09ce9fe8       83.915    1.7018  2018-03-22
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  37.247755    1.333000      1.366278    1.366278  1.366278         1.372712
# 1  24.694723         NaN           NaN         NaN       NaN              NaN
# 2  26.090457    1.167000      1.198091    1.198091  1.198091         1.203583
# 3  24.432662    1.350000      1.811507    1.811507  1.811507         1.786549
# 4  28.974941    1.200034      1.200034    1.200034  1.200000         1.191442
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...   3.280        113.050     106.0            1995.0     204.000000
# 1  ...  15.744        405.898     561.0            4614.0     316.695449
# 2  ...  12.350       4024.671      30.0            8451.0    1714.449840
# 3  ...   3.327      15650.106       2.0           25173.0    2238.127422
# 4  ...  54.556       2724.525      60.0           14912.0     657.744769
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0          113.050              0.000            0.000          0.000
# 1            0.000            405.898            0.000          0.000
# 2         1477.080           2547.591            0.000          0.000
# 3            0.000           3196.578        12453.528          0.000
# 4           21.305           2672.582            0.000         30.638
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  156fe69a-1c98-4337-b310-aee985e94279       60.781    1.6256  2016-04-02
# 1  15a31e8a-6944-49ef-9eac-83c455befe5b       80.739    1.7018  2016-03-04
# 2  15be065c-5661-4248-9677-0a3ee9345d76       66.224    1.8796  2018-07-29
# 3  15c80b51-b134-4a99-8b3f-79be70c8e28b       91.626    1.7018  2017-12-05
# 4  15e2ddf7-9627-4c9e-927b-834ec99d5c66       64.864    1.5494  2019-03-30
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  23.000669      1.2330      1.233000    1.233000  1.233000          1.23300
# 1  27.878303      1.3945      1.467000    1.394500  1.394500          1.39450
# 2  18.744961      1.0670      1.151167    1.151167  1.151167          1.15031
# 3  31.637466         NaN           NaN         NaN       NaN              NaN
# 4  27.019457         NaN           NaN         NaN       NaN              NaN
#
#    ...  value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  3.823          3.823       2.0               2.0         6881.4
# 1  ...    NaN            NaN       NaN               NaN            NaN
# 2  ...    NaN            NaN       NaN               NaN            NaN
# 3  ...    NaN            NaN       NaN               NaN            NaN
# 4  ...    NaN            NaN       NaN               NaN            NaN
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              0.0                0.0              0.0          3.823
# 1              NaN                NaN              NaN            NaN
# 2              NaN                NaN              NaN            NaN
# 3              NaN                NaN              NaN            NaN
# 4              NaN                NaN              NaN            NaN
#
#    ssq_score
# 0        5.0
# 1        4.0
# 2        2.0
# 3        NaN
# 4        3.0
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  17abe8f2-0992-4562-a91e-dd2fae4d40ce      104.780  1.778000  2018-07-05
# 1  17ebd137-5ce6-4df9-a894-83a36300f937       58.060  1.650667  2019-04-07
# 2  182be287-7340-4e71-8248-0782c7842335      114.759  1.778000  2018-09-24
# 3  1847672d-48cb-4e48-89c9-241d9db9f9a2       89.358  1.701800  2018-02-22
# 4  18488725-0ee7-4158-afa5-f3b72f7c8567       54.431  1.574800  2018-05-07
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  33.144760    1.022333      1.022333    1.022333  1.067000         1.022333
# 1  21.308764         NaN           NaN         NaN       NaN              NaN
# 2  36.301389         NaN           NaN         NaN       NaN              NaN
# 3  30.854350         NaN           NaN         NaN       NaN              NaN
# 4  21.948028    1.167724      1.533000    1.167724  1.167724         1.167724
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  48.870         48.870     440.0             440.0     399.845455
# 1  ...   9.710      14623.078       5.0            9428.0    5583.695460
# 2  ...  93.906        453.617     598.0            2214.0     737.588618
# 3  ...     NaN            NaN       NaN               NaN            NaN
# 4  ...  40.550        468.170     502.0            5244.0     321.398169
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              0.0              0.000            0.000         48.870
# 1             14.0           7112.196         7496.882          0.000
# 2              0.0              0.000            0.000        453.617
# 3              NaN                NaN              NaN            NaN
# 4              0.0            468.170            0.000          0.000
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        NaN
# 3        2.0
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  1a7380de-a7bc-4feb-90c7-835781f11406       78.018    1.7526  2018-09-30
# 1  1aaad641-a3b6-4e47-a010-e8cb01ce3d03       82.010    1.7526  2016-03-12
# 2  1ab9feeb-7440-46e6-99ca-33fa064c85fa       87.543    1.7526  2017-03-24
# 3  1abfcece-96d4-4b28-9da8-88b94372eb7a       93.440    1.8288  2016-03-05
# 4  1b179e96-26c8-4570-a1f8-15149d67d569      113.398    1.7272  2018-01-03
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  25.399736         NaN           NaN         NaN       NaN              NaN
# 1  26.699381    0.950000      1.663827    1.663827  1.663827         1.606575
# 2  28.500719    1.135157      1.135157    1.083000  1.135157         1.042324
# 3  27.938327    1.276600      1.276600    1.276600  1.233000         1.276600
# 4  38.011949         NaN           NaN         NaN       NaN              NaN
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...   4.640       2185.758       3.0            3594.0    2189.407012
# 1  ...   4.550       4599.950       2.0            2835.0    5841.206349
# 2  ...  78.253      32402.798     583.0          117660.0     991.416563
# 3  ...  39.820       1174.647     119.0            2794.0    1513.503651
# 4  ...     NaN            NaN       NaN               NaN            NaN
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0         1588.698            597.060            0.000          0.000
# 1           51.710           4548.240            0.000          0.000
# 2          217.744          20935.187        11202.715         47.152
# 3            0.000              0.000            0.000       1174.647
# 4              NaN                NaN              NaN            NaN
#
#    ssq_score
# 0        NaN
# 1        5.0
# 2        2.0
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  1e79b43c-e56e-4a93-9c52-36dd20237c5f       90.718    1.7780  2017-10-05
# 1  1e7fe9bf-6e76-4dfa-94b0-13293b5e38f5       58.967    1.6764  2019-01-16
# 2  1e9940f6-e47e-4165-a295-a6f6af6897f1      100.698    1.8288  2016-12-23
# 3  1f53ff27-cc84-44ae-9837-2a963c4d1b3d      113.852    1.8034  2016-03-03
# 4  1f7aa369-3811-40eb-802c-fcf6989f668d       81.647    1.8542  2017-12-04
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  28.696568    1.380385      1.500000    1.380385  1.380385         1.380385
# 1  20.982331         NaN           NaN         NaN       NaN              NaN
# 2  30.108451         NaN           NaN         NaN       NaN              NaN
# 3  35.007132    1.293200      1.293200    1.293200  1.233000         1.293200
# 4  23.748002    1.050000      1.056769    1.056769  1.056769         1.049669
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...   27.642       2523.484     420.0           16390.0     554.273484
# 1  ...  273.660        525.950     503.0            2225.0     850.975281
# 2  ...      NaN            NaN       NaN               NaN            NaN
# 3  ...      NaN            NaN       NaN               NaN            NaN
# 4  ...  194.482       4400.799     600.0           25609.0     618.644867
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0           27.642           2495.842            0.000          0.000
# 1            0.000              0.000            0.000        525.950
# 2              NaN                NaN              NaN            NaN
# 3              NaN                NaN              NaN            NaN
# 4            0.000           1774.335         2517.249        109.215
#
#    ssq_score
# 0        NaN
# 1        4.0
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  217d4ec8-9c15-47fd-a70c-af6c81b47f79       67.132    1.7018  2016-11-03
# 1  21976fac-52ed-4403-8fdc-1e92e87a2d8e      119.748    1.7018  2019-01-23
# 2  21980b64-b619-407f-b477-9d395326bfd8       83.455    1.8034  2016-03-02
# 3  21b0fa2e-1270-4295-b3d2-01d23585a4fc       90.718    1.6764  2019-02-15
# 4  21c85d4e-e242-4ff0-a46d-67151001920d       92.533    1.7272  2017-11-30
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  23.179953    1.338867      1.338867    1.338867  1.483000         1.338867
# 1  41.347688         NaN           NaN         NaN       NaN              NaN
# 2  25.660684    1.723005      0.917000    1.723005  1.723005         1.723005
# 3  32.280345    0.951574      0.800000    0.951574  0.951574         0.951574
# 4  31.017828         NaN           NaN         NaN       NaN              NaN
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...    3.141         50.739      62.0             428.0     426.776636
# 1  ...      NaN            NaN       NaN               NaN            NaN
# 2  ...    2.692      12001.173     360.0           22689.0    1904.192463
# 3  ...  132.800        499.405     468.0             956.0    1880.604603
# 4  ...   15.200       4187.100     597.0           12242.0    1231.298807
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0            0.000              0.000            0.000         50.739
# 1              NaN                NaN              NaN            NaN
# 2            0.000           1368.416        10570.737         62.020
# 3           11.942            388.806           98.657          0.000
# 4           15.860           4171.240            0.000          0.000
#
#    ssq_score
# 0        4.0
# 1        NaN
# 2        NaN
# 3        3.0
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  245870aa-d373-40ba-b36b-cb82c48c9528       69.400    1.7526  2017-12-01
# 1  245c1e33-5ef5-454b-a100-8d0884d568bf       45.359    1.5875  2018-05-11
# 2  24a9e57a-ea50-4705-befa-f0fe0a40952d       70.307    1.7526  2017-03-07
# 3  24b4813d-b8c6-4f11-8a13-0377964f284f       86.183    1.8288  2016-09-16
# 4  24f468b5-017d-446b-aa60-0d50ecf9f7c9       87.997    1.7526  2019-04-29
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  22.594038    0.963945      0.963945    0.963945  1.000000         0.963945
# 1  17.998487    1.167000      1.236167    1.236167  1.236167         1.236167
# 2  22.889323    1.114263      1.114263    1.114263  1.017000         1.055826
# 3  25.768503    1.117000      1.100416    1.100416  1.100416         1.100031
# 4  28.648524    1.133000      1.148300    1.148300  1.148300         1.148300
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  13.680        419.642     365.0            2889.0     522.918380
# 1  ...     NaN            NaN       NaN               NaN            NaN
# 2  ...  21.713        912.306     485.0            8067.0     407.128003
# 3  ...  34.747       3065.026      33.0           10234.0    1078.179949
# 4  ...  15.045        101.658      15.0             136.0    2690.947059
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0            0.000              0.000            0.000        419.642
# 1              NaN                NaN              NaN            NaN
# 2          231.188            640.904            0.000         40.214
# 3          552.094           1892.816          620.116          0.000
# 4          101.658              0.000            0.000          0.000
#
#    ssq_score
# 0        NaN
# 1        1.0
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  2763d67c-9eee-468f-a6ca-e2a153ab7bba      113.398    1.8288  2017-12-29
# 1  27764dd2-7e8e-4b2e-999e-4974c968c63e       83.915    1.7780  2018-01-03
# 2  27cae614-7207-4e3b-bcc0-effd45768c1d       66.678    1.7272  2016-03-04
# 3  285ee2d8-6cb1-4310-be97-ff42d0741c1c      131.542    1.7780  2018-12-28
# 4  2860b0bd-dd9e-4c7b-8ce4-4b7f20fa32b5       77.564    1.7272  2016-03-03
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  33.905720         NaN           NaN         NaN       NaN              NaN
# 1  26.544594    1.134368      1.134368    1.134368    1.1670         1.121321
# 2  22.351018    1.283694      1.283694    1.283694    1.0330         1.283694
# 3  41.610308    1.653700      1.653700    1.983000    1.6537         1.653700
# 4  26.000095    1.287761      1.287761    1.287761    1.6170         1.287761
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  78.410        761.962     425.0            4554.0     602.341502
# 1  ...   3.010       1282.322     419.0           13143.0     351.240904
# 2  ...   3.155        631.515       0.0            2002.0    1135.591409
# 3  ...  54.243       4570.679     101.0           17414.0     944.897462
# 4  ...  34.950       5021.317      38.0           18955.0     953.666114
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0            0.000            761.962            0.000          0.000
# 1            8.360              0.000            0.000       1273.962
# 2            0.000              0.000            0.000        631.515
# 3          859.471           3006.740          704.468          0.000
# 4            0.000           2959.395         1360.040        701.882
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  2aad1d92-45f9-4c85-89c3-009870dc82cd    75.175111    1.8288  2016-07-30
# 1  2ad365e5-1334-424a-920f-a9a681497926    99.790000    1.7526  2016-03-02
# 2  2b21d3f3-833d-43f0-b4a9-67874636cf3e   103.419000    1.5494  2019-06-07
# 3  2b715794-eb4e-4568-9c42-f90c294b9250    77.111000    1.7018  2018-11-16
# 4  2b77be16-45e3-4619-977f-95b039f86ca6    73.482000    1.6002  2018-11-29
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  22.477171    1.105077      1.105077    1.105077     1.100         1.105077
# 1  32.487883    1.346671      1.346671    1.346671     1.400         1.309999
# 2  43.079756    1.283267      1.283267    1.283267     1.367         1.283267
# 3  26.625593         NaN           NaN         NaN       NaN              NaN
# 4  28.696732    1.284091      1.284091    1.284091     1.000         1.284091
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...      NaN            NaN       NaN               NaN            NaN
# 1  ...    8.610       1115.725       5.0            5220.0     769.465517
# 2  ...   31.021        217.100      54.0             409.0    1910.904645
# 3  ...  114.190        138.390     422.0             591.0     842.984772
# 4  ...      NaN            NaN       NaN               NaN            NaN
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              NaN                NaN              NaN            NaN
# 1          140.938            974.787              0.0            0.0
# 2            0.000              0.000              0.0          217.1
# 3            0.000            138.390              0.0            0.0
# 4              NaN                NaN              NaN            NaN
#
#    ssq_score
# 0        NaN
# 1        3.0
# 2        NaN
# 3        2.0
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  2da37b15-4441-4aef-8c97-5af203fc61a1       83.007    1.7780  2017-11-30
# 1  2db4e485-960d-433e-80ca-a12ca795ca06       74.389    1.8034  2016-03-02
# 2  2dbe36f5-13c8-43e1-8772-3b5fe85e7879       53.070    1.5494  2018-02-07
# 3  2dd736da-add0-42f8-a9a0-66ed8e26c1de       75.750    1.7780  2016-03-03
# 4  2de34d13-38f5-4693-8c80-436c500e62ac       92.986    1.7780  2016-06-23
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  26.257369         NaN           NaN         NaN       NaN              NaN
# 1  22.873077    1.233000      1.526371    1.526371  1.526371         1.514414
# 2  22.106602         NaN           NaN         NaN       NaN              NaN
# 3  23.961783    1.267304      1.267304    1.267304  1.283000         1.267304
# 4  29.413998    1.157550      1.157550    1.367000  1.157550         1.157550
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...   42.517       5322.635     520.0           28701.0     667.624334
# 1  ...   49.800       3100.340     302.0            9703.0    1150.285891
# 2  ...  338.759       2646.673     598.0            7783.0    1224.209534
# 3  ...      NaN            NaN       NaN               NaN            NaN
# 4  ...  124.247       8174.207     295.0           19062.0    1543.759585
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0            0.000            771.788         4550.847          0.000
# 1          823.580           1992.560          284.200          0.000
# 2           41.730            823.813         1781.130          0.000
# 3              NaN                NaN              NaN            NaN
# 4           32.312           1761.080         5478.003        902.812
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        3.0
# 3        5.0
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  3069750d-f80b-4677-8772-f59d2dc8a8c7       66.678    1.7526  2019-05-05
# 1  30e3bfa8-58aa-4546-bae1-5b748a87814a      100.244    1.8288  2017-09-24
# 2  30e3ecbf-a78e-4746-af3b-3825fe8270c7       53.070    1.7780  2018-07-13
# 3  30faba9a-3458-40e9-864a-55d4158a73b6       54.431    1.6510  2019-04-24
# 4  3116db16-0ffe-4547-a26a-946fcd1870b3       95.254    1.8542  2018-12-31
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  21.707857         NaN           NaN         NaN       NaN              NaN
# 1  29.972707    1.433333      1.433333    1.433333     1.350         1.433333
# 2  16.787483         NaN           NaN         NaN       NaN              NaN
# 3  19.968809    1.325909      1.325909    1.325909     1.317         1.325909
# 4  27.705760         NaN           NaN         NaN       NaN              NaN
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  80.740        328.140     443.0            2139.0     552.269285
# 1  ...     NaN            NaN       NaN               NaN            NaN
# 2  ...  69.570       1461.580     504.0            8918.0     590.007625
# 3  ...  25.560        320.490      18.0             924.0    1248.662338
# 4  ...  17.575         31.378      62.0              70.0    1613.725714
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0           241.56                0.0             0.00         86.580
# 1              NaN                NaN              NaN            NaN
# 2             0.00                0.0          1461.58          0.000
# 3             0.00                0.0             0.00        320.490
# 4             0.00                0.0             0.00         31.378
#
#    ssq_score
# 0        NaN
# 1        3.0
# 2        1.0
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  34bd06c0-682c-472c-835e-db62c2241418       74.843    1.7780  2017-11-15
# 1  34bee5e4-93da-4878-806e-e6e453657abf       73.936    1.8288  2016-03-04
# 2  34bfd3cc-a10e-457d-a894-d57721460ce6       72.121    1.6002  2018-10-16
# 3  34c72292-937b-4ece-a52e-4ba57a08ffaf       94.801    1.7526  2017-09-13
# 4  34d58616-f9eb-4922-9365-210466d9cd97       87.090    1.7272  2017-11-16
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  23.674874    1.122529      1.122529      1.0500  1.122529         1.122529
# 1  22.106680    1.369500      1.369500      1.3695  1.150000         1.369500
# 2  28.165224         NaN           NaN         NaN       NaN              NaN
# 3  30.863651         NaN           NaN         NaN       NaN              NaN
# 4  29.193289         NaN           NaN         NaN       NaN              NaN
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  117.930       2109.266     453.0           13682.0     554.988861
# 1  ...      NaN            NaN       NaN               NaN            NaN
# 2  ...   16.330         48.460      25.0             321.0     543.476636
# 3  ...   16.683       1105.219     432.0           10446.0     380.891097
# 4  ...    7.810        591.710     368.0            5119.0     416.127369
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              0.0            412.758         1696.508          0.000
# 1              NaN                NaN              NaN            NaN
# 2              0.0              0.000            0.000         48.460
# 3              0.0              0.000            0.000       1105.219
# 4              0.0            591.710            0.000          0.000
#
#    ssq_score
# 0        NaN
# 1        5.0
# 2        4.0
# 3        4.0
# 4        4.0
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  3615284b-e952-447c-9ba3-3f2853c0cb23   105.167000    1.7018  2018-04-08
# 1  362812b2-c883-4637-9f02-64f04e5a463a    81.647000    1.9050  2018-11-06
# 2  362a923d-e9b9-433d-905f-37222fead8da    71.214000    1.7018  2017-12-09
# 3  36a6436a-f154-4486-902a-03f95352740a    64.988667    1.6256  2016-03-12
# 4  36fffc85-5749-47fa-8e70-d217254b4d07   110.677000    1.7780  2019-02-24
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  36.313027    1.359222      1.359222    1.359222  1.467000         1.359222
# 1  22.498329         NaN           NaN         NaN       NaN              NaN
# 2  24.589423    0.925889      0.925889    0.933000  0.925889         0.925889
# 3  24.592928    2.100012      1.183000    2.100012  2.100012         2.100012
# 4  35.010141         NaN           NaN         NaN       NaN              NaN
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...     NaN            NaN       NaN               NaN            NaN
# 1  ...  13.770         44.270       3.0             415.0     384.028916
# 2  ...     NaN            NaN       NaN               NaN            NaN
# 3  ...   6.106       5788.955       2.0           11126.0    1873.111451
# 4  ...     NaN            NaN       NaN               NaN            NaN
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              NaN                NaN              NaN            NaN
# 1              0.0              0.000            0.000          44.27
# 2              NaN                NaN              NaN            NaN
# 3              0.0           1807.569         3981.386           0.00
# 4              NaN                NaN              NaN            NaN
#
#    ssq_score
# 0        4.0
# 1        4.0
# 2        NaN
# 3        NaN
# 4        4.0
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  3951da48-3f90-44f7-82e1-1b17f1c4bc7c       61.235    1.6510  2017-12-03
# 1  395a47af-e742-4c00-a996-47b01e1f36bc       87.543    1.7526  2018-01-05
# 2  3986d266-7540-42be-a714-51905f4b873c      106.594    1.8542  2018-10-19
# 3  39bf0ad8-e79e-42e5-932b-365b5b59823a      103.873    1.7780  2018-05-25
# 4  39c63095-85ec-4d6d-a4ab-b902ad9190b4       83.007    1.7272  2019-02-15
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  22.464956    1.217000      1.116625    1.116625  1.116625         1.116625
# 1  28.500719    1.620717      1.620717    1.620717  1.650000         1.620717
# 2  31.004134    1.350000      1.350000    1.350000  1.417000         1.350000
# 3  32.857851         NaN           NaN         NaN       NaN              NaN
# 4  27.824634         NaN           NaN         NaN       NaN              NaN
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  12.250        130.696     501.0            1762.0     267.029285
# 1  ...  56.240       1374.359     492.0           14586.0     339.208309
# 2  ...     NaN            NaN       NaN               NaN            NaN
# 3  ...  42.160       1928.460     573.0           18226.0     380.909470
# 4  ...  13.438       3812.833      21.0            6830.0    2009.692357
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0          112.956              0.000             0.00         17.740
# 1            0.000              0.000             0.00       1374.359
# 2              NaN                NaN              NaN            NaN
# 3            0.000           1594.240           334.22          0.000
# 4            0.000           3812.833             0.00          0.000
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  3b06192e-b1db-4010-96b9-1531f9fc3e01       86.636    1.8034  2018-11-27
# 1  3b10ea5c-f1cf-4af0-bcd2-d76a5872c7da       49.895    1.6510  2018-02-25
# 2  3b14e997-0035-416f-8096-1319f6ceaf02       76.204    1.6764  2016-06-16
# 3  3b17bfa2-2532-4292-b7a3-110dd509dc75       74.389    1.7018  2017-12-07
# 4  3b3a7bca-ede0-4523-a660-d212301c87fa      113.398    1.7526  2017-05-15
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  26.638776    1.453091      1.383000    1.453091  1.453091         1.453091
# 1  18.304711    1.528818      1.528818    1.528818  1.350000         1.528818
# 2  27.115803    1.456016      1.456016    1.456016  1.617000         1.424998
# 3  25.685716         NaN           NaN         NaN       NaN              NaN
# 4  36.918137    1.418474      1.418474    1.418474  1.267000         1.418474
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...   95.720       1846.249     472.0           39009.0     170.383665
# 1  ...  279.160       1454.407     598.0            7192.0     728.012403
# 2  ...   89.981       5696.900     224.0           15984.0    1283.085586
# 3  ...    5.433       2061.701     363.0            9859.0     752.827224
# 4  ...      NaN            NaN       NaN               NaN            NaN
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0             0.00           1807.727              0.0         38.522
# 1             0.00              0.000              0.0       1454.407
# 2           295.03              0.000              0.0       5401.870
# 3            31.23              0.000              0.0       2030.471
# 4              NaN                NaN              NaN            NaN
#
#    ssq_score
# 0        2.0
# 1        3.0
# 2        4.0
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  3d68587e-f472-4dea-b3c1-bfde1667d659       77.111    1.7526  2019-05-23
# 1  3d9d3cc7-3f3a-4e7a-9ec5-e9b16d5f1a93       67.132    1.6256  2017-09-06
# 2  3dc28ae9-25e7-413f-9f89-e7119cc236ab      105.687    1.8796  2016-03-03
# 3  3ddd77c1-a39b-4125-a7ae-d7480f2b124c       66.224    1.7018  2018-10-06
# 4  3e3e731f-6620-47f5-a83b-b25fed121d09       99.790    1.7272  2017-05-12
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  25.104451         NaN           NaN         NaN       NaN              NaN
# 1  25.404006    1.197381         1.067    1.197381  1.197381         1.197381
# 2  29.915116         NaN           NaN         NaN       NaN              NaN
# 3  22.866430         NaN           NaN         NaN       NaN              NaN
# 4  33.450435         NaN           NaN         NaN       NaN              NaN
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  32.457         32.457     535.0             535.0     218.402243
# 1  ...  12.860      13052.291     365.0           20690.0    2271.060783
# 2  ...   6.820        830.010     360.0            3633.0     822.470685
# 3  ...  24.180         65.410     566.0             599.0     393.115192
# 4  ...     NaN            NaN       NaN               NaN            NaN
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0             0.00               0.00            0.000         32.457
# 1          1300.92            2619.06         9132.311          0.000
# 2             0.00               0.00            0.000        830.010
# 3             0.00               0.00            0.000         65.410
# 4              NaN                NaN              NaN            NaN
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        4.0
# 3        1.0
# 4        4.0
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  4101f561-623f-4eff-9435-cc5ead54f78e       74.843    1.6764  2018-05-11
# 1  41176db1-4453-4d1a-a37d-3bff6e6a8491       81.647    1.6256  2017-02-27
# 2  411868d8-9313-496a-81d9-8724a2b7163d      113.398    1.8034  2018-10-03
# 3  41263e01-6a95-4633-b9f1-3f1a1af8991a       83.915    1.8034  2018-09-23
# 4  414e88bc-1485-435e-afa6-535fec612a1c       95.254    1.7780  2017-11-28
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  26.631516    1.133000      1.112472    1.112472  1.112472         1.112472
# 1  30.896754    1.376584      1.083000    1.376584  1.376584         1.376584
# 2  34.867537         NaN           NaN         NaN       NaN              NaN
# 3  25.802125    1.101393      1.101393    1.101393  1.117000         1.026720
# 4  30.131428         NaN           NaN         NaN       NaN              NaN
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  71.481       5174.244     555.0           11704.0    1591.530964
# 1  ...  32.631       1094.974     599.0            8708.0     452.676435
# 2  ...  48.320        187.200     600.0            3415.0     197.341142
# 3  ...  61.440       6553.162      77.0           19811.0    1190.822432
# 4  ...  26.910        243.896     598.0            5921.0     148.290086
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0         5174.244              0.000              0.0          0.000
# 1           32.631           1062.343              0.0          0.000
# 2            0.000              0.000              0.0        187.200
# 3          860.229           5687.782              0.0          5.151
# 4            0.000              0.000              0.0        243.896
#
#    ssq_score
# 0        NaN
# 1        4.0
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  43b65366-aefe-4b0f-8186-b786a99fc90f     61.68900    1.6764  2016-03-22
# 1  43ee5202-a124-4370-bfee-83c1fbcccce3     70.30700    1.8288  2016-03-04
# 2  43fd2081-1375-44a9-befa-982d4e8244ea    104.32600    1.6510  2016-08-04
# 3  44660374-6043-4070-8deb-b5547d966ba3     90.71800    1.8288  2018-02-20
# 4  449c128b-5250-43e3-9abf-1ed3909f507f     93.11625    1.7200  2017-04-22
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  21.950905    1.308375      1.308375    1.308375     1.233         1.308375
# 1  21.021618    1.303333      1.303333    1.303333     1.150         1.303333
# 2  38.273520    1.403333      1.403333    1.403333     1.300         1.403333
# 3  27.124456         NaN           NaN         NaN       NaN              NaN
# 4  31.475206         NaN           NaN         NaN       NaN              NaN
#
#    ...  value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...    NaN            NaN       NaN               NaN            NaN
# 1  ...   1.54        1092.44     360.0            3892.0    1010.478931
# 2  ...  59.68        4014.24      91.0            3344.0    4321.550239
# 3  ...    NaN            NaN       NaN               NaN            NaN
# 4  ...    NaN            NaN       NaN               NaN            NaN
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              NaN                NaN              NaN            NaN
# 1              0.0                0.0              0.0        1092.44
# 2              0.0                0.0              0.0        4014.24
# 3              NaN                NaN              NaN            NaN
# 4              NaN                NaN              NaN            NaN
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        3.0
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  47294ee4-4817-4b02-ad26-09a4384ffba4       97.069    1.7526  2018-09-25
# 1  476313f3-6611-47d9-b53c-e869155ad9c3       64.864    1.5748  2018-02-19
# 2  476a1b47-12c2-4d3e-a138-85797931e84e       97.522    1.7272  2017-11-25
# 3  477f3db6-4213-4248-8cd8-6d01760ed84a       71.668    1.7272  2018-11-28
# 4  47aaa6b8-e2e0-4940-8418-459fecb9ebe4       74.843    1.6764  2019-01-03
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  31.602027     1.06700      1.236303    1.236303  1.236303         1.231173
# 1  26.154891         NaN           NaN         NaN       NaN              NaN
# 2  32.690182     1.41502      1.415020    1.415020  1.517000         1.415020
# ...
#
#    ssq_score
# 0        5.0
# 1        3.0
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  eed3097d-897c-4a59-861d-478e4448535a       75.750    1.7780  2018-09-15
# 1  eeda0d54-20ae-4ca0-be9e-ca403f0f51ef      157.397    1.9050  2017-11-05
# 2  ef01065e-2c8b-4804-a128-5a5b96d6cd17       80.286    1.7526  2017-05-20
# 3  ef05d277-9577-4474-952b-9884573f393b       71.214    1.7526  2016-03-03
# 4  ef0b25a0-b517-4ba4-8d78-3eb8d307e556      125.191    1.8796  2016-08-09
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  23.961783    1.408318      1.250000    1.408318  1.408318         1.408318
# 1  43.371705         NaN           NaN         NaN       NaN              NaN
# 2  26.138112    0.934774      0.934774    0.934774  0.883000         0.934774
# 3  23.184608    1.158025      1.158025    1.158025  1.150000         1.159789
# 4  35.435800    1.624615      1.624615    1.624615  1.550000         1.624615
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  59.998       5764.607     505.0           35543.0     583.872639
# 1  ...  16.840        310.326     406.0            2340.0     477.424615
# 2  ...     NaN            NaN       NaN               NaN            NaN
# 3  ...  16.610      19097.310      15.0           26199.0    2624.158021
# 4  ...     NaN            NaN       NaN               NaN            NaN
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0            23.87           2390.586         3350.151           0.00
# 1             0.00            310.326            0.000           0.00
# 2              NaN                NaN              NaN            NaN
# 3         14869.16           2721.270         1324.440         182.44
# 4              NaN                NaN              NaN            NaN
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        4.0
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  f219380a-c469-46d9-a206-289f9b5f9b42       69.400    1.6002  2017-02-05
# 1  f22f645e-2fad-4a5c-a324-13e26e84362e       66.224    1.7272  2016-03-22
# 2  f23c564d-f0aa-43de-91eb-65f84b08c5f8       80.739    1.7018  2016-03-04
# 3  f25dde7b-c120-4261-92ef-5b9483ab35b2       63.503    1.8034  2017-12-29
# 4  f25faa11-da8c-4bab-b837-d272a49a057d       72.620    1.7526  2016-06-25
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  27.102599    1.248286      1.248286    1.248286     1.350         1.248286
# 1  22.198833    1.316667      1.316667    1.316667     1.150         1.316667
# 2  27.878303    1.261833      1.261833    1.261833     1.283         1.261833
# 3  19.525857         NaN           NaN         NaN       NaN              NaN
# 4  23.642349    1.095812      1.095812    1.095812     1.017         1.095812
#
#    ...  value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  85.92       9768.181      61.0           15213.0    2311.539578
# 1  ...  32.90        818.814      64.0            2397.0    1229.758198
# 2  ...   5.36         32.780      62.0              74.0    1594.702703
# 3  ...    NaN            NaN       NaN               NaN            NaN
# 4  ...  25.26       2253.350      38.0            3693.0    2196.604387
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              0.0                0.0         8881.871        886.310
# 1              0.0                0.0            0.000        818.814
# 2              0.0                0.0            0.000         32.780
# 3              NaN                NaN              NaN            NaN
# 4              0.0                0.0            0.000       2253.350
#
#    ssq_score
# 0        NaN
# 1        3.0
# 2        NaN
# 3        NaN
# 4        4.0
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  f3f37736-a61f-414e-903a-9de0d92d1ded      61.6890    1.7272  2016-04-02
# 1  f42888c2-8f09-4a7b-b5c9-4456aeffb86f      50.8020    1.7018  2016-03-22
# 2  f4436753-a421-4a7f-8160-01b1b88feedb     146.5002    1.8288  2016-03-25
# 3  f453dd22-c99e-45ee-bb3f-eecbb258f5f7      86.1830    1.8288  2017-03-01
# 4  f47281e0-4ed8-4210-8a56-3a19a1b95b19      84.3680    1.8796  2016-03-03
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  20.678664    1.131200      1.017000    1.131200    1.1312         1.131200
# 1  17.541381    1.349833      1.349833    1.349833    1.5500         1.349833
# 2  43.803195    1.263455      1.263455    1.263455    1.2500         1.263455
# 3  25.768503    1.262962      1.262962    1.262962    1.3670         1.262962
# 4  23.880691    1.200000      1.200000    1.200000    1.2000         1.200000
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...    7.155       1061.692      20.0            2879.0    1327.575964
# 1  ...   30.140       5519.030      95.0           13751.0    1444.877318
# 2  ...  405.330       3381.190     250.0            5930.0    2052.661720
# 3  ...      NaN            NaN       NaN               NaN            NaN
# 4  ...   41.090       1550.129      82.0            3316.0    1682.890350
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              0.0              34.82          204.461        822.411
# 1              0.0               0.00            0.000       5519.030
# 2              0.0               0.00            0.000       3381.190
# 3              NaN                NaN              NaN            NaN
# 4              0.0               0.00            0.000       1550.129
#
#    ssq_score
# 0        NaN
# 1        3.0
# 2        NaN
# 3        3.0
# 4        4.0
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  f63675b8-bc5b-496c-b370-50acfb13fc9f       83.915    1.8542  2018-01-18
# 1  f6781389-b3ac-4fa5-834f-ffeb35c8d897      105.233    1.9050  2018-08-06
# 2  f6b0f802-6212-4824-a63f-987e4a796bb5       77.111    1.7272  2019-04-06
# 3  f6b9b67c-ae55-4bbd-be9c-2d932542a40a       99.790    1.5748  2019-01-12
# 4  f6d52426-a7c5-4b60-a496-1ef1e6985dc8       74.843    1.8288  2019-05-02
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  24.407677         NaN           NaN         NaN       NaN              NaN
# 1  28.997596    1.000000      1.072554    1.072554  1.072554         1.092033
# 2  25.848246    1.014685      1.014685    1.014685  1.033000         1.009920
# 3  40.237984         NaN           NaN         NaN       NaN              NaN
# 4  22.377871         NaN           NaN         NaN       NaN              NaN
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...    6.860        252.101     493.0            5586.0     162.471106
# 1  ...  178.707       1589.726     595.0            7798.0     733.907874
# 2  ...  383.520       1076.632     542.0            2270.0    1707.434009
# 3  ...      NaN            NaN       NaN               NaN            NaN
# 4  ...   32.960         32.960      66.0              66.0    1797.818182
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0          182.614              0.000              0.0         69.487
# 1            0.000           1589.726              0.0          0.000
# 2           30.306           1016.279              0.0         30.047
# 3              NaN                NaN              NaN            NaN
# 4            0.000              0.000              0.0         32.960
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  f9284acc-cc58-43d5-805c-d904aad0620e      100.244    1.7272  2019-03-12
# 1  f93130c1-78bb-48f1-b1b5-78da399ca09c      113.398    1.7018  2018-01-28
# 2  f957a354-0991-4e14-acfd-622a0eb33578       72.121    1.7018  2017-06-10
# 3  f95c6d3a-0077-40c2-b991-0290ba081ff4      135.624    1.7526  2019-04-07
# 4  f9c3bdb5-43cd-4c00-a80f-624337c8c2bb       73.028    1.6256  2018-03-29
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  33.602619    1.233000      1.264436    1.264436  1.264436         1.266442
# 1  39.155102         NaN           NaN         NaN       NaN              NaN
# 2  24.902600         NaN           NaN         NaN       NaN              NaN
# 3  44.154090    1.137708      1.137708    1.137708  1.250000         1.088459
# 4  27.635163         NaN           NaN         NaN       NaN              NaN
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...  20.288        567.770      80.0            1941.0    1053.051005
# 1  ...     NaN            NaN       NaN               NaN            NaN
# 2  ...  40.750        714.890     585.0            6240.0     412.436538
# 3  ...  26.590        103.950      26.0             339.0    1103.893805
# 4  ...  10.562        318.736     368.0            4880.0     235.133115
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0          250.588               0.00              0.0        317.182
# 1              NaN                NaN              NaN            NaN
# 2            0.000               0.00              0.0        714.890
# 3            0.000             103.95              0.0          0.000
# 4            0.000               0.00              0.0        318.736
#
#    ssq_score
# 0        1.0
# 1        NaN
# 2        3.0
# 3        1.0
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  fbaa2dbf-8c99-4a1a-9e66-182607774a1f      134.717    1.9304  2017-09-06
# 1  fbd4d6f8-4471-4757-9a94-b187ce9b71b2       78.925    1.6510  2018-10-28
# 2  fc30959f-c046-4a2c-ac50-b6974e71ec14       85.729    1.7272  2018-05-13
# 3  fcb1d876-9681-423c-92fa-c3adf946f121       68.039    1.5748  2017-05-18
# 4  fcf0b482-9610-4fd0-9fae-4417fc93651d       90.718    1.7780  2018-06-14
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  36.151622         NaN           NaN         NaN       NaN              NaN
# 1  28.954792    1.067000      1.213189    1.213189  1.213189         1.195610
# 2  28.737071         NaN           NaN         NaN       NaN              NaN
# 3  27.435136    1.265686      1.265686    1.265686  1.467000         1.265686
# 4  28.696568    1.126600      1.126600    1.126600  1.083000         1.126600
#
#    ...  value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...    NaN            NaN       NaN               NaN            NaN
# 1  ...  40.18        253.636     187.0            1035.0     882.212174
# 2  ...  35.79         35.790     401.0             401.0     321.306733
# 3  ...   5.12       1496.600     297.0            7828.0     688.267757
# 4  ...  37.80        271.373     411.0            2864.0     341.111313
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              NaN                NaN              NaN            NaN
# 1          117.806                0.0              0.0        135.830
# 2            0.000                0.0              0.0         35.790
# 3            0.000                0.0              0.0       1496.600
# 4            0.000                0.0              0.0        271.373
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        3.0
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  ff43c783-192c-4b10-845a-82c8ae64d54a     72.57500    1.7780  2016-03-03
# 1  ff4f01fb-1636-4687-934d-58f18fae4f6a     90.71800    1.7272  2018-12-25
# 2  ff58667a-9661-4ecb-bcd1-45e8ca8f6a6a    153.31400    1.8796  2017-12-18
# 3  ff6df296-8405-4398-804e-be282447795c     68.03900    1.6764  2018-09-04
# 4  ff724463-e3c3-4da9-83cc-3f57d81b095a     84.09625    1.6510  2018-09-29
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  22.957444    1.249750      1.249750    1.249750    1.3830         1.249750
# 1  30.409425    1.018500      1.100000    1.018500    1.0185         1.018500
# 2  43.396124         NaN           NaN         NaN       NaN              NaN
# 3  24.210436    1.361765      1.361765    1.361765    1.3500         1.354055
# 4  30.851940    1.413200      1.413200    1.413200    1.4170         1.413200
#
#    ...   value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...     NaN            NaN       NaN               NaN            NaN
# 1  ...   4.350        141.150       2.0            1180.0     430.627119
# 2  ...  14.570       2531.810     455.0           20193.0     451.370079
# 3  ...   7.042         93.522     548.0            1329.0     253.332731
# 4  ...     NaN            NaN       NaN               NaN            NaN
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0              NaN                NaN              NaN            NaN
# 1            0.000             141.15              0.0          0.000
# 2            0.000               0.00              0.0       2531.810
# 3           54.131               0.00              0.0         39.391
# 4              NaN                NaN              NaN            NaN
#
#    ssq_score
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 42 columns]
# DataFrame 0: (77, 42)
# DataFrame 1: (120, 42)
# DataFrame 2: (190, 42)
# DataFrame 3: (378, 42)
# DataFrame 4: (205, 42)
# DataFrame 5: (65, 42)
# DataFrame 6: (252, 42)
# DataFrame 7: (95, 42)
# DataFrame 8: (135, 42)
# DataFrame 9: (164, 42)
# DataFrame 10: (43, 42)
# DataFrame 11: (117, 42)
# DataFrame 12: (79, 42)
# DataFrame 13: (71, 42)
# DataFrame 14: (268, 42)
# DataFrame 15: (109, 42)
# DataFrame 16: (167, 42)
# DataFrame 17: (97, 42)
# DataFrame 18: (268, 42)
# DataFrame 19: (166, 42)
# DataFrame 20: (192, 42)
# DataFrame 21: (243, 42)
# DataFrame 22: (198, 42)
# DataFrame 23: (866, 42)
# DataFrame 24: (50, 42)
# DataFrame 25: (99, 42)
# DataFrame 26: (261, 42)
# DataFrame 27: (192, 42)
# DataFrame 28: (84, 42)
# DataFrame 29: (349, 42)
# DataFrame 30: (68, 42)
# DataFrame 31: (58, 42)
# DataFrame 32: (157, 42)
# DataFrame 33: (197, 42)
# DataFrame 34: (72, 42)
# DataFrame 35: (681, 42)
# DataFrame 36: (712, 42)
# DataFrame 37: (170, 42)
# DataFrame 38: (309, 42)
# DataFrame 39: (473, 42)
# DataFrame 40: (147, 42)
# DataFrame 41: (156, 42)
# DataFrame 42: (100, 42)
# DataFrame 43: (122, 42)
# DataFrame 44: (257, 42)
# DataFrame 45: (204, 42)
# DataFrame 46: (156, 42)
# DataFrame 47: (170, 42)
# DataFrame 48: (53, 42)
# DataFrame 49: (51, 42)
# DataFrame 50: (415, 42)
# DataFrame 51: (194, 42)
# DataFrame 52: (462, 42)
# DataFrame 53: (239, 42)
# DataFrame 54: (258, 42)
# DataFrame 55: (190, 42)
# DataFrame 56: (202, 42)
# DataFrame 57: (84, 42)
# DataFrame 58: (89, 42)
# DataFrame 59: (621, 42)
# DataFrame 60: (93, 42)
# DataFrame 61: (1182, 42)
# DataFrame 62: (48, 42)
# DataFrame 63: (835, 42)
# DataFrame 64: (143, 42)
# DataFrame 65: (72, 42)
# DataFrame 66: (134, 42)
# DataFrame 67: (350, 42)
# DataFrame 68: (612, 42)
# DataFrame 69: (355, 42)
# DataFrame 70: (231, 42)
# DataFrame 71: (146, 42)
# DataFrame 72: (276, 42)
# DataFrame 73: (405, 42)
# DataFrame 74: (158, 42)
# DataFrame 75: (221, 42)
# DataFrame 76: (50, 42)
# DataFrame 77: (334, 42)
# DataFrame 78: (111, 42)
# DataFrame 79: (309, 42)
# DataFrame 80: (72, 42)
# DataFrame 81: (174, 42)
# DataFrame 82: (53, 42)
# DataFrame 83: (150, 42)
# DataFrame 84: (510, 42)
# DataFrame 85: (82, 42)
# DataFrame 86: (149, 42)
# DataFrame 87: (384, 42)
# DataFrame 88: (569, 42)
# DataFrame 89: (29, 42)

# %%
# For each unique participant, check if they have a value for weight, height, and bmi. If so, copy values to each row for that participant

for df in subset_dfs:

    # Loop through participants
    for participant in df['participantId'].unique():
        # Find the index of the row containing non NaN values for weight, height, and bmi
        non_nan_index = df[(df['participantId'] == participant) & (~df['bodyMass_kg'].isnull()) & (~df['height_m'].isnull()) & (~df['bmi'].isnull())].index

        # If there is a row with non NaN values, copy the values to all rows for that participant
        if len(non_nan_index) > 0:
            non_nan_index = non_nan_index[0]
            non_nan_row = df.loc[non_nan_index]
            df.loc[df['participantId'] == participant, 'bodyMass_kg'] = non_nan_row['bodyMass_kg']
            df.loc[df['participantId'] == participant, 'height_m'] = non_nan_row['height_m']
            df.loc[df['participantId'] == participant, 'bmi'] = non_nan_row['bmi']
    print(f"DataFrame : {df.shape}")
# Out:
# DataFrame : (77, 42)
# DataFrame : (120, 42)
# DataFrame : (190, 42)
# DataFrame : (378, 42)
# DataFrame : (205, 42)
# DataFrame : (65, 42)
# DataFrame : (252, 42)
# DataFrame : (95, 42)
# DataFrame : (135, 42)
# DataFrame : (164, 42)
# DataFrame : (43, 42)
# DataFrame : (117, 42)
# DataFrame : (79, 42)
# DataFrame : (71, 42)
# DataFrame : (268, 42)
# DataFrame : (109, 42)
# DataFrame : (167, 42)
# DataFrame : (97, 42)
# DataFrame : (268, 42)
# DataFrame : (166, 42)
# DataFrame : (192, 42)
# DataFrame : (243, 42)
# DataFrame : (198, 42)
# DataFrame : (866, 42)
# DataFrame : (50, 42)
# DataFrame : (99, 42)
# DataFrame : (261, 42)
# DataFrame : (192, 42)
# DataFrame : (84, 42)
# DataFrame : (349, 42)
# DataFrame : (68, 42)
# DataFrame : (58, 42)
# DataFrame : (157, 42)
# DataFrame : (197, 42)
# DataFrame : (72, 42)
# DataFrame : (681, 42)
# DataFrame : (712, 42)
# DataFrame : (170, 42)
# DataFrame : (309, 42)
# DataFrame : (473, 42)
# DataFrame : (147, 42)
# DataFrame : (156, 42)
# DataFrame : (100, 42)
# DataFrame : (122, 42)
# DataFrame : (257, 42)
# DataFrame : (204, 42)
# DataFrame : (156, 42)
# DataFrame : (170, 42)
# DataFrame : (53, 42)
# DataFrame : (51, 42)
# DataFrame : (415, 42)
# DataFrame : (194, 42)
# DataFrame : (462, 42)
# DataFrame : (239, 42)
# DataFrame : (258, 42)
# DataFrame : (190, 42)
# DataFrame : (202, 42)
# DataFrame : (84, 42)
# DataFrame : (89, 42)
# DataFrame : (621, 42)
# DataFrame : (93, 42)
# DataFrame : (1182, 42)
# DataFrame : (48, 42)
# DataFrame : (835, 42)
# DataFrame : (143, 42)
# DataFrame : (72, 42)
# DataFrame : (134, 42)
# DataFrame : (350, 42)
# DataFrame : (612, 42)
# DataFrame : (355, 42)
# DataFrame : (231, 42)
# DataFrame : (146, 42)
# DataFrame : (276, 42)
# DataFrame : (405, 42)
# DataFrame : (158, 42)
# DataFrame : (221, 42)
# DataFrame : (50, 42)
# DataFrame : (334, 42)
# DataFrame : (111, 42)
# DataFrame : (309, 42)
# DataFrame : (72, 42)
# DataFrame : (174, 42)
# DataFrame : (53, 42)
# DataFrame : (150, 42)
# DataFrame : (510, 42)
# DataFrame : (82, 42)
# DataFrame : (149, 42)
# DataFrame : (384, 42)
# DataFrame : (569, 42)
# DataFrame : (29, 42)

# %%
# Concatenate the DataFrames in subset_dfs into a single DataFrame

# empty DataFrame
concatenated_df = pd.DataFrame() 

concatenated_df = pd.concat(subset_dfs, ignore_index=True)

print(concatenated_df.head())
print(concatenated_df.shape)

# remove rows with NaN
concatenated_df = concatenated_df.dropna()

# remove duplicates of participantId and startDate
concatenated_df.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)

# Save the concatenated DataFrame to a CSV file
#concatenated_df.to_csv(save_path + 'all_data.csv', index=False)
# Out:
#                           participantId  bodyMass_kg  height_m   startDate  \
# 0  00a55fb5-da33-4e2e-ae61-28f589fcc174       51.256    1.5748  2016-05-12
# 1  00d6d2ee-ccea-45c7-9772-b19fd9bef2bf       74.389    1.9050  2018-04-20
# 2  00fd4039-9b5e-4bbb-8295-4983a3f58371       59.874    1.6510  2018-08-15
# 3  0113e483-0fc8-4892-a4fc-0b2f3820dde3       68.039    1.7018  2019-03-06
# 4  013d82d7-b3cc-4007-b00c-4d1d75bab9dd       76.204    1.6002  2018-02-21
#
#          bmi  morning_hr  afternoon_hr  evening_hr  night_hr  mean_hr_morning  \
# 0  20.667783    1.400000      1.438426    1.438426  1.438426         1.438137
# 1  20.498343         NaN           NaN         NaN       NaN              NaN
# 2  21.965653    1.290195      1.290195    1.290195  1.383000         1.266626
# 3  23.493130    1.292230      1.000000    1.292230  1.292230         1.292230
# 4  29.759747         NaN           NaN         NaN       NaN              NaN
#
#    ...    value  totalDistance  duration  dwrTotalDuration  dist_per_hour  \
# 0  ...   17.730       3970.370      15.0            8567.0    1668.417416
# 1  ...      NaN            NaN       NaN               NaN            NaN
# 2  ...   21.890         46.270      61.0            1441.0     115.594726
# 3  ...  199.902       5085.913     597.0            7537.0    2429.253921
# 4  ...   11.100         30.590     380.0            1320.0      83.427273
#
#    morningDistance  afternoonDistance  eveningDistance  nightDistance  \
# 0          1123.06           2456.180          391.130          0.000
# 1              NaN                NaN              NaN            NaN
# 2             0.00              0.000            0.000         46.270
# 3             0.00           3055.634         1996.413         33.866
# 4             0.00              0.000            0.000         30.590
#
#    ssq_score
# 0        3.0
# 1        NaN
# 2        4.0
# 3        NaN
# 4        3.0
#
# [5 rows x 42 columns]
# (20904, 42)

# %%
# remove rows with NaN
concatenated_df = concatenated_df.dropna()

# remove duplicates of participantId and startDate
concatenated_df.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)

concatenated_df.to_csv(save_path + 'activity-timed-data.csv', index=False)

# %%
# Merge the surveys DataFrame with the concatenated DataFrame

activity_and_survey_df = pd.merge(concatenated_df, df_surveys, on=['participantId'], how='outer', suffixes=('', '_y'))

#print(activity_and_survey_df.head())

# Print num rows
print(f"Number of rows in activity_and_survey_df before NaN removed: {len(activity_and_survey_df)}")

# Remove rows that have NaN values
activity_and_survey_df = activity_and_survey_df.dropna()

print(f"Number of rows in activity_and_survey_df after NaN removed: {len(activity_and_survey_df)}")

print(activity_and_survey_df.head())
print(activity_and_survey_df.shape)

activity_and_survey_df.to_csv(save_path + 'timed_df.csv', index=False)
# Out:
# '# Merge the surveys DataFrame with the concatenated DataFrame\n\nactivity_and_survey_df = pd.merge(concatenated_df, df_surveys, on=[\'participantId\'], how=\'outer\', suffixes=(\'\', \'_y\'))\n\n#print(activity_and_survey_df.head())\n\n# Print num rows\nprint(f"Number of rows in activity_and_survey_df before NaN removed: {len(activity_and_survey_df)}")\n\n# Remove rows that have NaN values\nactivity_and_survey_df = activity_and_survey_df.dropna()\n\nprint(f"Number of rows in activity_and_survey_df after NaN removed: {len(activity_and_survey_df)}")\n\nprint(activity_and_survey_df.head())\nprint(activity_and_survey_df.shape)\n\nactivity_and_survey_df.to_csv(save_path + \'timed_df.csv\', index=False)\n'

# %%
# remove rows where startDate and participant Id are duplicated

activity_and_survey_df.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)
# Out:
# "# remove rows where startDate and participant Id are duplicated\n\nactivity_and_survey_df.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)"

# %%
'''# Drop rows with NaN values
#activity_and_survey_df = activity_and_survey_df.dropna()

# Save the final DataFrame to a CSV file
activity_and_survey_df.to_csv(save_path + 'final_timed_data.csv', index=False)'''
# Out:
# "# Drop rows with NaN values\n#activity_and_survey_df = activity_and_survey_df.dropna()\n\n# Save the final DataFrame to a CSV file\nactivity_and_survey_df.to_csv(save_path + 'final_timed_data.csv', index=False)"

# %%
'''print(activity_and_survey_df.head(10))'''
# Out:
# 'print(activity_and_survey_df.head(10))'

# %%
'''# add the AMCH and PMCH data to the activity_and_survey_df based on participantId and startDate

activity_and_survey_df = pd.merge(activity_and_survey_df, df_amch, on=['participantId', 'startDate'], how='outer', suffixes=('', '_y'))
#activity_and_survey_df = pd.merge(activity_and_survey_df, df_pmch, on=['participantId', 'startDate'], how='outer', suffixes=('', '_y'))
print(activity_and_survey_df.shape)

# drop duplicates of participantId and startDate
activity_and_survey_df.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)


# drop nan values
activity_and_survey_df = activity_and_survey_df.dropna()
print(activity_and_survey_df.shape)
'''
# Out:
# "# add the AMCH and PMCH data to the activity_and_survey_df based on participantId and startDate\n\nactivity_and_survey_df = pd.merge(activity_and_survey_df, df_amch, on=['participantId', 'startDate'], how='outer', suffixes=('', '_y'))\n#activity_and_survey_df = pd.merge(activity_and_survey_df, df_pmch, on=['participantId', 'startDate'], how='outer', suffixes=('', '_y'))\nprint(activity_and_survey_df.shape)\n\n# drop duplicates of participantId and startDate\nactivity_and_survey_df.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)\n\n\n# drop nan values\nactivity_and_survey_df = activity_and_survey_df.dropna()\nprint(activity_and_survey_df.shape)\n"

# %%
'''activity_and_survey_df.to_csv(save_path + 'timed-data-with-am.csv', index=False)'''
# Out:
# "activity_and_survey_df.to_csv(save_path + 'timed-data-with-am.csv', index=False)"

# %%
'''activity_and_survey_df = pd.merge(activity_and_survey_df, df_pmch, on=['participantId', 'startDate'], how='outer', suffixes=('', '_y'))
activity_and_survey_df = activity_and_survey_df.dropna()

# drop duplicates of participantId and startDate
activity_and_survey_df.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)

print(activity_and_survey_df.shape)'''
# Out:
# "activity_and_survey_df = pd.merge(activity_and_survey_df, df_pmch, on=['participantId', 'startDate'], how='outer', suffixes=('', '_y'))\nactivity_and_survey_df = activity_and_survey_df.dropna()\n\n# drop duplicates of participantId and startDate\nactivity_and_survey_df.drop_duplicates(subset=['participantId', 'startDate'], inplace=True)\n\nprint(activity_and_survey_df.shape)"

# %%
'''# save to csv

activity_and_survey_df.to_csv(save_path + 'timed-data-with-am-pm.csv', index=False)'''
# Out:
# "# save to csv\n\nactivity_and_survey_df.to_csv(save_path + 'timed-data-with-am-pm.csv', index=False)"
